# %%
# %matplotlib notebook
import datajoint as dj
schema = dj.schema('common_psy', locals())
schema.spawn_missing_classes()
dj.ERD(schema).draw(prefix_module=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook
import datajoint as dj
schema = dj.schema('pipeline_rf', locals())
schema.spawn_missing_classes()
dj.ERD(schema).draw(prefix_module=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook
import datajoint as dj
import expe
(dj.ERD(expe)).draw(prefix_module=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
expe.PMTChannel()
# Out:
# animal_id     session     pmt_channel    pmt_filter     notes
# +-----------+ +---------+ +------------+ +------------+ +-------+
#  (0 tuples)

# %%
# %matplotlib notebook
import datajoint as dj
import expe
import prep
(dj.ERD(prep)).draw(prefix_module=True)
# Out:
# /usr/local/lib/python3.5/site-packages/scipy/optimize/_basinhopping.py:291: RuntimeWarning: overflow encountered in exp
#   w = min(1.0, np.exp(-(energy_new - energy_old) * self.beta))
# <img src="data:image/png;base64,...">

# %%
prep.ExtractRaw().drop()
# Out:
# `pipe_preprocessing`.`_extract_raw` (0 tuples)
# `pipe_preprocessing`.`_extract_raw__sync` (0 tuples)
# `pipe_preprocessing`.`_extract_raw__segment` (0 tuples)
# `pipe_preprocessing`.`_extract_raw__raw_trace` (0 tuples)
# `pipe_preprocessing`.`_extract_raw__import_aod` (0 tuples)
# `pipe_preprocessing`.`_extract_raw__point` (0 tuples)
# Proceed? [yes, No]: yes
# Tables dropped.
