# %% [markdown]
# # Pipeline: manual data in schema `experiment`

# %% [markdown]
# ## Setup notebook appearance

# %%
# make notebook display width scalable
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

# make figures bigger
# %pylab inline
pylab.rcParams['figure.figsize'] = (9, 7)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Import manual schemas

# %%
from datajoint import ERD
from pipeline import mice, experiment
# Out:
# DataJoint 0.2.8 (July 1, 2016)
# Loading local settings from dj_local_conf.json

# %% [markdown]
# Here are the dependencies within the `experiment` schema:

# %%
ERD(experiment).draw(prefix=False)

# %% [markdown]
# Note that `Session` references `mice.Mice`, so the mouse information must already exist:

# %%
(ERD(experiment.Session)-1).draw()

# %% [markdown]
# ## Manual tables
# During multiphoton imaging experiments, users must enter informaiton into three tables in the `experiment` schema:
# 1. `Session`
# 1. `Session.Fluorophore`
# 1. `Scan`
#
# Below are previews of contents of these tables:

# %%
experiment.Session()
# Out:
# *animal_id    *session    rig     session_date   username     anesthesia     pmt_filter_set scan_path      craniotomy_not session_notes  session_ts
# +-----------+ +---------+ +-----+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
# 7588          1           2P3     2016-02-08     jake         awake          2P3 red-green  /scratch01/Two                ;;Nestin-GCaMP 2016-02-08 15:
# 7588          2           2P3     2016-02-09     jake         awake          2P3 red-green  /scratch01/Two                ;;Nestin-GCaMP 2016-02-09 22:
# 7816          1           2P3     2016-02-10     jake         awake          2P3 red-green  /scratch01/Two                ;;Emx1 Cre     2016-02-11 10:
# 8158          1           2P3     2016-02-14     jake         awake          2P3 red-green  /scratch01/Two                ;;Twitch targe 2016-02-14 14:
# 8341          1           2P3     2016-02-15     jake         awake          2P3 red-green  /scratch01/Two                ;;NEstin/GCaMP 2016-02-15 15:
# 8487          1           2P3     2016-02-26     unknown      awake          2P3 red-green  /scratch01/Two                Emx1/ZtTA/Ai93 2016-02-26 17:
# 8623          1           2P3     2016-02-17     jake         awake          2P3 red-green  /scratch01/Two                CamKII-tTA/tet 2016-02-17 13:
# ...
#  (39 tuples)

# %%
experiment.Session.Fluorophore()
# Out:
# *animal_id    *session    *fluorophore   notes
# +-----------+ +---------+ +------------+ +-------+
# 7588          1           GCaMP6s
# 7588          2           GCaMP6s
# 7816          1           GCaMP6s
# 8158          1           Twitch2B
# 8341          1           GCaMP6s
# 8487          1           GCaMP6f
# 8623          1           GCaMP6s
# ...
#  (39 tuples)

# %% [markdown]
# For each scan, entries must be filled out in `experiment.Scan`:

# %%
experiment.Scan()
# Out:
# *animal_id    *session    *scan_idx    lens     brain_area     laser_waveleng laser_power    filename       aim       depth     scan_notes     site_number    software      version     scan_ts
# +-----------+ +---------+ +----------+ +------+ +------------+ +------------+ +------------+ +------------+ +-------+ +-------+ +------------+ +------------+ +-----------+ +---------+ +------------+
# 7588          1           1            25x      V1             920.0          60.0           m7588A_00001   unset     160       flashing bar   1              scanimage     5.1         2016-02-08 15:
# 7588          1           4            25x      V1             920.0          60.0           m7588A_00004   unset     160       trippy/monet   4              scanimage     5.1         2016-02-08 16:
# 7588          2           2            25x      V1             920.0          60.0           m7588A_00002   unset     260       triipy/monet   1              scanimage     5.1         2016-02-09 22:
# 7816          1           11           25x      V1             920.0          35.0           m7816A_00011   unset     80                       1              scanimage     5.1         2016-02-11 11:
# 7816          1           20           25x      V1             920.0          37.0           m7816A_00020   unset     102                      2              scanimage     5.1         2016-02-11 11:
# 7816          1           24           25x      V1             920.0          38.0           m7816A_00024   unset     124                      3              scanimage     5.1         2016-02-11 11:
# 7816          1           26           25x      V1             920.0          41.0           m7816A_00026   unset     145                      4              scanimage     5.1         2016-02-11 11:
# ...
#  (181 tuples)

# %% [markdown]
# Next: [pipeline_preprocess](pipeline_preprocess.ipynb)

# %% [markdown]
# # MATLAB

# %%
# %load_ext pymatbridge
# Out:
# /usr/local/lib/python3.5/site-packages/IPython/nbformat.py:13: ShimWarning: The `IPython.nbformat` package has been deprecated. You should import from nbformat instead.
#   "You should import from nbformat instead.", ShimWarning)
# Starting MATLAB on ZMQ socket ipc:///tmp/pymatbridge-7fbf5127-7b44-4fb6-a263-9a61a878f087
# Send 'exit' command to kill the server
# ........MATLAB started and connected!

# %%
# %%matlab
# run ~/dev/startup.m   % set paths and database credentials
# Out:
# No connections open
# mym is now ready for use.

# %%
# %%matlab
# erd experiment
# g = gcf()
# set(g, 'PaperSize', [8 6])
# Out:
#  0:  at-database via TCP/IP           Server version 5.6.30-0ubuntu0.14.04.1-log
#
# g =
#
#   Figure (1) with properties:
#
#       Number: 1
#         Name: ''
#        Color: [0.94 0.94 0.94]
#     Position: [440 378 560 420]
#        Units: 'inches'
#
#   Use GET to show all properties

# %%
# %%matlab
# x = -5:0.01:5;
# plot(x, cos(x))
# Out:
# ---------------------------------------------------------------------------
# MatlabInterperterError                    Traceback (most recent call last)
# <ipython-input-11-d46107971242> in <module>()
# ----> 1 get_ipython().run_cell_magic('matlab', '', 'x = -5:0.01:5;\nplot(x, cos(x))')
#
# /usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2118             magic_arg_s = self.var_expand(line, stack_depth)
#    2119             with self.builtin_trap:
# -> 2120                 result = fn(magic_arg_s, cell)
#    2121             return result
#    2122
#
# <decorator-gen-358> in matlab(self, line, cell, local_ns)
#
# /usr/local/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /usr/local/lib/python3.5/site-packages/pymatbridge/matlab_magic.py in matlab(self, line, cell, local_ns)
#     161
#     162         try:
# --> 163             result_dict = self.eval(code)
#     164         except MatlabInterperterError:
#     165             raise
#
# /usr/local/lib/python3.5/site-packages/pymatbridge/matlab_magic.py in eval(self, line)
#      88
#      89         if not run_dict['success']:
# ---> 90             raise MatlabInterperterError(line, run_dict['content']['stdout'])
#      91
#      92         # This is the matlab stdout:
#
# MatlabInterperterError: Failed to parse and evaluate line 'x = -5:0.01:5;\nplot(x, cos(x))'.
#  Matlab error message: 'Images must contain fewer than 2^32 - 1 bytes of data.'
